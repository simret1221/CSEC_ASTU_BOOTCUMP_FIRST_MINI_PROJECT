# %% [markdown]
# <a href="https://colab.research.google.com/github/simret1221/CSEC_ASTU_BOOTCUMP_FIRST_MINI_PROJECT/blob/main/continual_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git clone https://github.com/simret1221/Continual_Learning_assignment_Third_Icog_Labs-_Task-.git
# Out:
# Cloning into 'Continual_Learning_assignment_Third_Icog_Labs-_Task-'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd Continual_Learning_assignment_Third_Icog_Labs-_Task-
# Out:
# /content/Continual_Learning_assignment_Third_Icog_Labs-_Task-

# %%
# !ls
# Out:
# README.md

# %%
# !mkdir -p data
# !mkdir -p models
# !mkdir -p methods
# !mkdir -p training
# !mkdir -p evaluation
# !mkdir -p visualization
# !mkdir -p results/figures
# !mkdir -p results/tables
# !mkdir -p results/checkpoints
# !mkdir -p report

# %%
# !find . -maxdepth 2 -type d
# Out:
# .
# ./evaluation
# ./models
# ./methods
# ./training
# ./results
# ./results/figures
# ./results/tables
# ./results/checkpoints
# ./.git
# ./.git/refs
# ./.git/objects
# ./.git/logs
# ./.git/branches
# ./.git/info
# ./.git/hooks
# ./visualization
# ./report
# ./data

# %%
# !touch data/mnist_loader.py
# !touch data/permuted_mnist.py

# !touch models/cnn.py

# !touch methods/replay.py
# !touch methods/ewc.py

# !touch training/trainer.py

# !touch evaluation/metrics.py
# !touch evaluation/evaluator.py

# !touch visualization/plots.py

# !touch main.py
# !touch requirements.txt
# !touch .gitignore

# %%
# !pip install torch torchvision matplotlib numpy pandas scikit-learn tqdm

# %%
import torch
import torchvision
import numpy as np

print("PyTorch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
print("NumPy:", np.__version__)

print("Environment Ready 🚀")
# Out:
# PyTorch: 2.11.0+cpu
# Torchvision: 0.26.0+cpu
# NumPy: 2.0.2
# Environment Ready 🚀

# %%
# !pip freeze > requirements.txt

# %%
# !cat requirements.txt
# Out:
# absl-py==1.4.0
# accelerate==1.14.0
# access==1.1.10.post3
# affine==2.4.0
# aiofiles==25.1.0
# aiohappyeyeballs==2.7.1
# aiohttp==3.14.1
# aiosignal==1.4.0
# aiosqlite==0.22.1
# alabaster==1.0.0
# albucore==0.0.24
# albumentations==2.0.8
# ale-py==0.12.0
# altair==5.5.0
# annotated-doc==0.0.4
# annotated-types==0.7.0
# antlr4-python3-runtime==4.9.3
# anyio==4.14.2
# anywidget==0.9.21
# apsw==3.53.3.1
# apswutils==0.1.2
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# array_record==0.8.3
# arrow==1.4.0
# arviz==0.22.0
# astropy==7.2.2
# astropy-iers-data==0.2026.7.13.0.54.2
# astunparse==1.6.3
# atpublic==5.1
# attrs==26.1.0
# audioread==3.1.0
# Authlib==1.7.2
# autograd==1.9.1
# babel==2.18.0
# backcall==0.2.0
# beartype==0.22.9
# beautifulsoup4==4.13.5
# betterproto==2.0.0b6
# bigframes==2.42.0
# bigquery-magics==0.14.0
# bleach==6.4.0
# blinker==1.9.0
# blis==1.3.3
# blobfile==3.2.0
# blosc2==4.8.0
# bokeh==3.8.2
# Bottleneck==1.4.2
# bqplot==0.12.47
# branca==0.8.2
# ...

# %%
# %%writefile README.md
#
# # Continual Learning Framework
#
# ## Overview
#
# This project studies catastrophic forgetting in neural networks.
#
# The goal is to train a CNN sequentially on MNIST and Permuted MNIST tasks and evaluate continual learning strategies.
#
# ## Dataset
#
# - MNIST
# - Permuted MNIST
#
# ## Methods
#
# - Baseline CNN
# - Experience Replay
# - Elastic Weight Consolidation (EWC)
#
# ## Technologies
#
# - Python
# - PyTorch
# - Google Colab
# - GitHub
#
# ## Project Structure
# Out:
# Overwriting README.md

# %%
# %%writefile .gitignore
#
# __pycache__/
# *.pyc
#
# .ipynb_checkpoints/
#
# *.pth
# *.pt
#
# results/checkpoints/
# Out:
# Overwriting .gitignore
